# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# Objective: Use Python programming techniques to filter and order data subsets, group data by one or more variables, and use aggregation functions to obtain insights, and derive meaningful conclusions from the data.

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.

# %% [markdown]
# Start by reading the dataset, standardizing column names, dealing with null values and creating the month column. You can do so by using the functions you developed in previous labs, or by reading the clean dataset you saved in the last lab `data structuring and combining`.

# %% [markdown]
# Then, answer the following questions:

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %% [markdown]
# 2. Analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign.

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %% [markdown]
# 4. Find the median customer lifetime value by education level and gender.

# %% [markdown]
# 5. Find the maximum, minimum, and average number of open complaints by state and policy type.

# %% [markdown]
# 6. The marketing team wants to analyze the number of policies sold by state and month.
#
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 7. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 8. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')
data
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
data.isnull().sum().sum()
# Out:
# 9254

# %%
data.dropna()
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 10             10  HG93801     Arizona              5154.764074       No
# 13             13  KR82385  California              5454.587929       No
# 16             16  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
data.columns = data.columns.str.lower().str.replace(' ', '_')

# %%
data['Effective To Date'] = pd.to_datetime(data['Effective To Date'])  
data['month'] = data['Effective To Date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Effective To Date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Create a new DataFrame that only includes customers who have a total_claim_amount greater 
# than $1,000 and have a response of "Yes" to the last marketing campaign.

data_filtered = data[(data['total_claim_amount'] > 1000) & (data['response'] == 'Yes')]
data_filtered
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 236           236  YJ16163      Oregon             11009.130490      Yes
# 419           419  GW43195      Oregon             25807.063000      Yes
# 442           442  IP94270     Arizona             13736.132500      Yes
# 587           587  FJ28407  California              5619.689084      Yes
# 1527         1527  TU53781      Oregon              8427.172486      Yes
# 1809         1809  QO62792      Oregon              7840.165778      Yes
# 2027         2027  TA66375      Oregon             11009.130490      Yes
# 2125         2125  JC11405      Oregon             10963.957230      Yes
# 2865         2865  FH77504  California             11009.130490      Yes
# 3958         3958  KC26486     Arizona              8427.172486      Yes
# 4475         4475  WP58340     Arizona             10963.957230      Yes
# 4521         4521  LT72149      Nevada              5619.689084      Yes
# ...

# %%
# Analyze the average total_claim_amount by each policy type and gender for 
# customers who have responded "Yes" to the last marketing campaign

filtered_customers = data[data['response'] == 'Yes']

average_claim_amount = filtered_customers.groupby(['policy_type', 'gender'])['total_claim_amount'].mean()
average_claim_amount
# Out:
# policy_type     gender
# Corporate Auto  F         404.104008
#                 M         391.370774
# Personal Auto   F         457.056315
#                 M         472.489180
# Special Auto    F         495.689401
#                 M         368.523035
# Name: total_claim_amount, dtype: float64

# %%
# Analyze the total number of customers who have policies in each state, 
# and then filter the results to only include states where there are more than 500 customers.


customer_count_by_state = data.groupby('state')['customer'].count().reset_index()
customer_count_by_state.rename(columns={'customer': 'customer_count'}, inplace=True)

states_with_more_than_500_customers = customer_count_by_state[customer_count_by_state['customer_count'] > 500]
states_with_more_than_500_customers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 7
#       1 # Analyze the total number of customers who have policies in each state,
#       2 # and then filter the results to only include states where there are more than 500 customers.
#       5 customer_count_by_state = data.groupby('state')['customer'].count().reset_index()
# ----> 7 states_with_more_than_500_customers = customer_count_by_state[customer_count_by_state > 500]
#       8 states_with_more_than_500_customers
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
# ...

# %%
# Find the median customer lifetime value by education level and gender.

median_customer_l_ifetime_value = data.groupby(['education', 'gender'])['customer_lifetime_value'].median().reset_index()

median_customer_l_ifetime_value
# Out:
#               education gender  customer_lifetime_value
# 0              Bachelor      F              5752.485185
# 1              Bachelor      M              5797.377350
# 2               College      F              5642.596077
# 3               College      M              6005.847375
# 4                Doctor      F              5789.850900
# 5                Doctor      M              5843.989737
# 6  High School or Below      F              5978.754765
# 7  High School or Below      M              6081.481291
# 8                Master      F              5714.165863
# 9                Master      M              5512.342258

# %%
# Find the maximum, minimum, and average number of open complaints by state and policy type.

values_of_open_complaints = data.groupby(['state', 'policy_type'])['number_of_open_complaints'].agg(['max', 'min', 'mean']).reset_index()

values_of_open_complaints
# Out:
#          state     policy_type  max  min      mean
# 0      Arizona  Corporate Auto  5.0  0.0  0.456790
# 1      Arizona   Personal Auto  5.0  0.0  0.413374
# 2      Arizona    Special Auto  3.0  0.0  0.229167
# 3   California  Corporate Auto  4.0  0.0  0.296703
# 4   California   Personal Auto  5.0  0.0  0.398589
# 5   California    Special Auto  4.0  0.0  0.388889
# 6       Nevada  Corporate Auto  3.0  0.0  0.393617
# 7       Nevada   Personal Auto  5.0  0.0  0.422492
# 8       Nevada    Special Auto  3.0  0.0  0.285714
# 9       Oregon  Corporate Auto  4.0  0.0  0.331984
# 10      Oregon   Personal Auto  5.0  0.0  0.373444
# 11      Oregon    Special Auto  5.0  0.0  0.328571
# 12  Washington  Corporate Auto  4.0  0.0  0.467532
# 13  Washington   Personal Auto  5.0  0.0  0.409836
# 14  Washington    Special Auto  4.0  0.0  0.562500

# %%
# The marketing team wants to analyze the number of policies sold by state and month.
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])

data['month'] = data['effective_to_date'].dt.month

policies_by_state_month = data.pivot_table(index='state', columns='month', values='number_of_policies', aggfunc='sum', fill_value=0)

policies_by_state_month
# Out:
# month          1     2
# state
# Arizona     1344  1297
# California  2439  2158
# Nevada       666   567
# Oregon      2009  1885
# Washington   585   589

# %%
# Display a new DataFrame that contains the number of policies sold by month by state for the top 3 
# states with the highest number of policies sold.
# Hint:

# To accomplish this, you will first need to group the data by state and month, then count the number of policies 
# sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.
# Next, you will select the top 3 states with the highest number of policies sold.
# Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.

policies_by_state_month = data.groupby(['state', 'month'])['number_of_policies'].count().reset_index()

sorted_policies = policies_by_state_month.sort_values(by='number_of_policies', ascending=False)

top_3_states = sorted_policies['state'].head(3)

top_3_states_policies = sorted_policies[sorted_policies['state'].isin(top_3_states)]

top_3_states_policies
# Out:
#         state  month  number_of_policies
# 2  California      1                 826
# 3  California      2                 726
# 6      Oregon      1                 676
# 7      Oregon      2                 605

# %%
# The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
# Hint: You can use melt to unpivot the data and create a table that shows the customer response
# rate (those who responded "Yes")by marketing channel.


melted_data = pd.melt(data, id_vars=['response', 'sales_channel'], value_vars=['customer'], var_name='customer_type', value_name='customer_id')

melted_data = melted_data[melted_data['response'] == 'Yes']

response_rate = melted_data.groupby('sales_channel')['response'].count() / melted_data.groupby('sales_channel')['response'].size()

response_rate
# Out:
# sales_channel
# Agent          1.0
# Branch         1.0
# Call Center    1.0
# Web            1.0
# Name: response, dtype: float64
